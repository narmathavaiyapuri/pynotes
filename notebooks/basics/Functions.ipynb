# %%
# Basic function
def greet():
    print("Hello!")

greet()
# Out:
# Hello!

# %%
# Function with parameter
def greet(name):
    print("Hello", name)

greet("Narmatha")
# Out:
# Hello Narmatha

# %%
# Function with return
def add(a, b):
    return a + b

result = add(10, 5)
print("Sum:", result)
# Out:
# Sum: 15
