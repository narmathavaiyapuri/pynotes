# %%
# Basic lambda
add = lambda a, b: a + b

print(add(10, 5))
# Out:
# 15

# %%
# Lambda with condition
check = lambda x: "Even" if x % 2 == 0 else "Odd"

print(check(7))
# Out:
# Odd

# %%
# Lambda with list
nums = [1, 2, 3, 4]

result = list(map(lambda x: x * 2, nums))

print(result)
# Out:
# [2, 4, 6, 8]
