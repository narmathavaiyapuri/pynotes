# %%
# Import full module
import math

print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
# Import specific functions
from math import sqrt, pow

print(sqrt(25))
print(pow(2, 3))
# Out:
# 5.0
# 8.0

# %%
# Import specific functions
from math import sqrt, pow

print(sqrt(25))
print(pow(2, 3))
# Out:
# 5.0
# 8.0
