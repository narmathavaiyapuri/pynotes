# %%
# String basics
text = "Hello World"

print("Text:", text)
print("Length:", len(text))
# Out:
# Text: Hello World
# Length: 11

# %%
# String operations
name = "Narmatha"

print(name.upper())
print(name.lower())
print(name.replace("a", "@"))
# Out:
# NARMATHA
# narmatha
# N@rm@th@

# %%
# Loop through string
word = "Python"

for ch in word:
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n
